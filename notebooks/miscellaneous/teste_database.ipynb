# %%
import pandas as pd

# %%
import sqlite3
from pathlib import Path

# Caminho absoluto para o arquivo do banco de dados
DB_PATH = Path("wtnps-trade.db")

"""Retorna uma conexão SQLite para o banco wtnps-trade.db."""
sqlite3.connect(DB_PATH)
